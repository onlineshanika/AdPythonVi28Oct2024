# %%
# Datatypes ---- It defines the type of data a variable can Hold or maintain

#
# Datatypes ------ 1. Primitive Datatype
#                  2. Collection Datatype
#
#                                               Primitive Types
#                                                     |
#       -------------------------------------------------------------------------------------------------------
#       |                                             |                                                       |
#  Numbers                                        String                                                  Boolean
#       |
#  ------------------------------------
#  |               |                  |
# Integers       Decimals       Complex
# (int)          (float)

# %%
# Execute the cell
#  Shift+Enter

#Python is a type-inferred language
# Type Inference means the system will automatically identify and assign datatype to the variable based on the data assigned to the variable
num1 = 10

# %%
# type() ---- Used to identify the datatype of the given variable
type(num1)
# Out:
# int

# %%
num2 = 2.4
type(num2)
# Out:
# float

# %%
demo = "Welcome to Python Programming"
type(demo)
# Out:
# str

# %%
num3 = 3+4j
type(num3)
# Out:
# complex

# %%
num4 = True
type(num4)
# Out:
# bool

# %%
#Printing data

print(num1)
# Out:
# 10

# %%
print(demo)
# Out:
# Welcome to Python Programming

# %%
#Creating String
# Single Quote
# Double Quote
# Triple Single Quote

# %%
print(' Welcome to python ')
# Out:
#  Welcome to python

# %%
print("Welcome")
# Out:
# Welcome

# %%
print('''
                    Welcome to Python
              ==============================
              1. Datatype
              2. Format


''')
# Out:
#                     Welcome to Python
# ...
#               1. Datatype
#               2. Format

# %%
num1 = 10
num2 = 20

print("Given num1 variable contains ", num1)
# Out:
# Given num1 variable contains  10

# %%
print("Given num1 variable contains {} and num2 contains {}".format(num1,num2))
# Out:
# Given num1 variable contains 10 and num2 contains 20

# %%
#F-string method
print(f"Given num1 variable contains {num1} and num2 contains {num2}")
# Out:
# Given num1 variable contains 10 and num2 contains 20
