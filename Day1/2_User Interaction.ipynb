# %%
# User Interaction Demo
# Accept the input from the user --------------------- input()
#input() accepts data from user in the form of STRING datatype

# %%
#Simple Greeting Example

name = input("Enter your name: ")
print("Hello", name)
# Out:
# Enter your name: Prashant
# Hello Prashant

# %%
type(name2)
# Out:
# str

# %%
name2 = input("Enter your name: ")
print("Hello", name2)
# Out:
# Enter your name: 56
# Hello 56

# %%
#Typecasting --- Typecasting is all about converting the datatype of variable from one form to another
# such that the value matches teh datatype

# %%
#Create a program to accept two number from user and perform addition of two numbers

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
result = num1 + num2
print(f"Addition of {num1} and {num2} is {result} ")
# Out:
# Enter first number: 4
# Enter second number: 3
# Addition of 4.0 and 3.0 is 7.0

# %%
type(num2)
# Out:
# str

# %%
int("50")
# Out:
# 50
